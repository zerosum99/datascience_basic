# %% [markdown]
# ## 예제 14-1-1 모듈을 이용해서 데이터 가저오기

# %% [markdown]
# ### 참조 자료
#
#    https://financedata.github.io/posts/finance-data-reader-users-guide.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5) # 이 두줄은 본 필자가 항상 쓰는 방법입니다. matplotlib 의 기본 scheme 말고 seaborn scheme 을 세팅하고, 일일이 graph 의 font size 를 지정할 필요 없이 seaborn 의 font_scale 을 사용하면 편합니다.

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
import sys
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.font_manager as font_manager

font_list = font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

# %%
if sys.platform == 'darwin' : 
    path = '/System/Library/Fonts/Supplemental/AppleGothic.ttf'
    font_name = fm.FontProperties(fname=path, size=50).get_name()
    print(font_name)
    plt.rc('font', family=font_name)

else :
    plt.rc('font', family='Malgun Gothic')
# Out:
# AppleGothic

# %%
import FinanceDataReader as fdr

# %%
fdr.__version__
# Out:
# '0.9.31'

# %% [markdown]
# ###   차트 설정

# %%
plt.rcParams["font.family"] =  "Malgun Gothic"
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams["axes.grid"] = True

# %% [markdown]
# ## 상장기업 정보 가져오기

# %%
df_krx = fdr.StockListing('KRX')

# %%
type(df_krx)
# Out:
# pandas.core.frame.DataFrame

# %%
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 이현우         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도

# %%
## 변경전

# %%
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 이현우         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도

# %%
df_krx.tail()
# Out:
#       Symbol  Market     Name                    Sector  \
# 7368  000547   KOSPI  흥국화재2우B                       NaN
# 7369  000545   KOSPI    흥국화재우                       NaN
# 7370  003280   KOSPI     흥아해운                    해상 운송업
# 7371  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7372  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 7368                             NaN         NaT         NaN
# 7369                             NaN         NaT         NaN
# 7370                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 7371                       설계 및 감리용역  2000-02-03         12월
# 7372  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#                  Representative                HomePage Region
# 7368                        NaN                     NaN    NaN
# 7369                        NaN                     NaN    NaN
# 7370                        이환구  http://www.heung-a.com  서울특별시
# 7371  정영균, 이목운, 허철호, 염두성 (각자대표)   http://www.heerim.com  서울특별시
# 7372                        김주환   http://www.hims.co.kr  인천광역시

# %%
## 변경전

# %%
df_krx.tail()
# Out:
#       Symbol  Market     Name                    Sector  \
# 7368  000547   KOSPI  흥국화재2우B                       NaN
# 7369  000545   KOSPI    흥국화재우                       NaN
# 7370  003280   KOSPI     흥아해운                    해상 운송업
# 7371  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7372  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 7368                             NaN         NaT         NaN
# 7369                             NaN         NaT         NaN
# 7370                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 7371                       설계 및 감리용역  2000-02-03         12월
# 7372  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#                  Representative                HomePage Region
# 7368                        NaN                     NaN    NaN
# 7369                        NaN                     NaN    NaN
# 7370                        이환구  http://www.heung-a.com  서울특별시
# 7371  정영균, 이목운, 허철호, 염두성 (각자대표)   http://www.heerim.com  서울특별시
# 7372                        김주환   http://www.hims.co.kr  인천광역시

# %%
df_krx.shape, df_krx.ndim, df_krx.size
# Out:
# ((7373, 10), 2, 73730)

# %%
df_krx.values
# Out:
# array([['060310', 'KOSDAQ', '3S', ..., '박종익, 김세완 (각자 대표이사)',
#         'http://www.3sref.com', '서울특별시'],
#        ['095570', 'KOSPI', 'AJ네트웍스', ..., '이현우',
#         'http://www.ajnet.co.kr', '서울특별시'],
#        ['006840', 'KOSPI', 'AK홀딩스', ..., '채형석, 이석주(각자 대표이사)',
#         'http://www.aekyunggroup.co.kr', '서울특별시'],
#        ...,
#        ['003280', 'KOSPI', '흥아해운', ..., '이환구', 'http://www.heung-a.com',
#         '서울특별시'],
#        ['037440', 'KOSDAQ', '희림', ..., '정영균, 이목운, 허철호, 염두성 (각자대표)',
#         'http://www.heerim.com', '서울특별시'],
#        ['238490', 'KOSDAQ', '힘스', ..., '김주환', 'http://www.hims.co.kr',
#         '인천광역시']], dtype=object)

# %%
df_krx.columns
# Out:
# Index(['Symbol', 'Market', 'Name', 'Sector', 'Industry', 'ListingDate',
#        'SettleMonth', 'Representative', 'HomePage', 'Region'],
#       dtype='object')

# %%
df_krx.dtypes
# Out:
# Symbol                    object
# Market                    object
# Name                      object
# Sector                    object
# Industry                  object
# ListingDate       datetime64[ns]
# SettleMonth               object
# Representative            object
# HomePage                  object
# Region                    object
# dtype: object

# %%
df_krx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7373 entries, 0 to 7372
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          7373 non-null   object
#  1   Market          7373 non-null   object
#  2   Name            7373 non-null   object
#  3   Sector          2426 non-null   object
#  4   Industry        2407 non-null   object
#  5   ListingDate     2426 non-null   datetime64[ns]
#  6   SettleMonth     2426 non-null   object
#  7   Representative  2426 non-null   object
#  8   HomePage        2248 non-null   object
#  9   Region          2426 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 633.6+ KB

# %% [markdown]
# ### 결측치 정리

# %%
df_krx['isnan'] = df_krx.isna()['Industry']

# %%
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region  isnan
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시  False
# 1         12월                 이현우         http://www.ajnet.co.kr  서울특별시  False
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시  False
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도  False
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도  False

# %%
d = df_krx[df_krx['isnan'] == True]

# %%
d.shape
# Out:
# (4966, 11)

# %%
d.head()
# Out:
#     Symbol Market                Name Sector Industry ListingDate SettleMonth  \
# 6   152100  KOSPI         ARIRANG 200    NaN      NaN         NaT         NaN
# 7   295820  KOSPI     ARIRANG 200동일가중    NaN      NaN         NaT         NaN
# 8   253150  KOSPI   ARIRANG 200선물레버리지    NaN      NaN         NaT         NaN
# 9   253160  KOSPI  ARIRANG 200선물인버스2X    NaN      NaN         NaT         NaN
# 10  278420  KOSPI     ARIRANG ESG우수기업    NaN      NaN         NaT         NaN
#
#    Representative HomePage Region  isnan
# 6             NaN      NaN    NaN   True
# 7             NaN      NaN    NaN   True
# 8             NaN      NaN    NaN   True
# 9             NaN      NaN    NaN   True
# 10            NaN      NaN    NaN   True

# %%
import numpy as np

# %%
df_krx['Industry'] =  np.where(df_krx['isnan'] == True, df_krx['Sector'], df_krx['Industry'])

# %%
df_krx.loc[82]
# Out:
# Symbol                                       004840
# Market                                        KOSPI
# Name                                          DRB동일
# Sector                                       기타 금융업
# Industry          고무벨트(V벨트,콘베이어벨트,평벨트),프라스틱제품 제조,판매
# ListingDate                     1976-05-21 00:00:00
# SettleMonth                                     12월
# Representative                                  류영식
# HomePage                        http://drbworld.com
# Region                                        부산광역시
# isnan                                         False
# Name: 82, dtype: object

# %%
df_krx['Industry'].isna().sum()
# Out:
# 4947

# %%
del df_krx['isnan']

# %%
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 이현우         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도

# %%
df_005930 = fdr.DataReader('005930', '2018','2019')

# %%
df_005930.head()
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2018-01-02  51380  51400  50780  51020  169485  0.001177
# 2018-01-03  52540  52560  51420  51620  200270  0.011760
# 2018-01-04  52120  52180  50640  51080  233909 -0.010461
# 2018-01-05  51300  52120  51200  52120  189623  0.020360
# 2018-01-08  52400  52520  51500  52020  167673 -0.001919

# %%
df_005930.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count    244.000000    244.000000    244.000000    244.000000  2.440000e+02
# mean   46216.147541  46699.627049  45690.122951  46830.122951  7.767970e+06
# std     6211.325438   6260.034968   6087.189644   3452.522485  7.354287e+06
# min        0.000000      0.000000      0.000000  38250.000000  0.000000e+00
# 25%    44447.500000  44887.500000  44000.000000  44700.000000  3.153292e+05
# 50%    46755.000000  47175.000000  46250.000000  46850.000000  8.268154e+06
# 75%    49612.500000  50185.000000  49080.000000  49627.500000  1.168827e+07
# max    53380.000000  54140.000000  52440.000000  53000.000000  6.349111e+07
#
#            Change
# count  244.000000
# mean    -0.000985
# std      0.016883
# min     -0.048565
# 25%     -0.011149
# 50%      0.000000
# 75%      0.008765
# max      0.047450

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_005930['Close'], color='b', 
                 label='Skewness : {:.2f}'.format(df_005930['Close'].skew()),
                 ax=ax)
g = g.legend(loc='best')

# %%
df_000660 = fdr.DataReader('000660', '2018','2019')

# %%
df_000660.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count    244.000000    244.000000    244.000000    244.000000  2.440000e+02
# mean   78567.622951  79562.295082  77417.213115  78449.180328  3.814150e+06
# std     8163.215250   8162.519258   8052.841869   8123.448212  1.558810e+06
# min    58200.000000  59400.000000  58100.000000  58600.000000  1.489091e+06
# 25%    72200.000000  73275.000000  71125.000000  72125.000000  2.694338e+06
# 50%    78800.000000  79700.000000  77750.000000  78750.000000  3.362270e+06
# 75%    85000.000000  86025.000000  83625.000000  84525.000000  4.684567e+06
# max    95300.000000  97700.000000  94600.000000  95300.000000  1.037892e+07
#
#            Change
# count  244.000000
# mean    -0.000708
# std      0.022570
# min     -0.070535
# 25%     -0.014834
# 50%      0.000000
# 75%      0.012152
# max      0.069585

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_000660['Close'], 
                 color='b', 
                 label='Skewness : {:.2f}'.format(df_000660['Close'].skew()),
                 ax=ax)
g = g.legend(loc='best')
plt.show()

# %%
fig, ax = plt.subplots(1, 1)
ax = df_005930['Close'].plot(figsize=(12, 8))
ax = df_000660['Close'].plot(figsize=(12, 8))
plt.show()

# %% [markdown]
# ### 종가 누적 합 구하기

# %%
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(111)
plt.plot(df_005930.index,df_005930['Volume'],label="삼성전자")
plt.plot(df_000660.index,df_000660['Volume'],label="하이닉스")
plt.xticks(rotation=70)
plt.legend(loc='best')
plt.show()

# %%
df_cummax_005930 = df_005930['Close'].cummax()

# %%
df_cummax_005930.plot(figsize=(12, 5))

# %%
ax1=plt.subplot(1, 1, 1)

df_cummax_005930.plot(ax=ax1)
df_005930['Close'].plot(figsize=(12, 5), ax=ax1)

# %%
df_cummax_000660 = df_000660['Close'].cummax()

# %%
ax1=plt.subplot(1, 1, 1)

df_cummax_000660.plot(ax=ax1)
df_000660['Close'].plot(figsize=(12, 5), ax=ax1)

# %%
import mpl_finance

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)
mpl_finance.candlestick2_ohlc(ax, df_000660['Open'],
                                  df_000660['High'],
                                  df_000660['Low'], 
                                  df_000660['Close'],
                                  width=1.5, colorup='r', colordown='b')

plt.show()

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)
mpl_finance.candlestick2_ohlc(ax, df_005930['Open'],
                                  df_005930['High'],
                                  df_005930['Low'], 
                                  df_005930['Close'],
                                  width=1.5, colorup='r', colordown='b')

plt.show()

# %%
df_000660['20d'] = np.round(df_000660["Close"].rolling(window=20).mean(), 2)

# %%
df_000660['60d'] = np.round(df_000660["Close"].rolling(window= 60).mean(), 2)

# %%
df_000660['120d'] = np.round(df_000660["Close"].rolling(window=120).mean(), 2)

# %%
df_000660['20-120'] = df_000660['20d'] - df_000660['120d']

# %%
df_000660['20-60'] = df_000660['20d'] - df_000660['60d']

# %%
df_000660[['Close','20d','60d','120d']].plot(figsize=(20,5))

# %%
SD = 65

# %%
df_000660['매매구간'] = np.where(df_000660['20-120']> SD,1,0)

# %%
df_000660['매매구간'] = np.where(df_000660['20-120'] < -SD, -1, df_000660['매매구간'])

# %%
df_000660['매매구간'].plot(lw=1.5)

# %%
fig = plt.figure(figsize=(12, 8))
ax3 = fig.add_subplot(111)
(df_000660['120d']/df_005930['Close'].max()).plot(ax=ax3)
(df_000660['60d']/df_005930['Close'].max()).plot(ax=ax3)
(df_000660['20d']/df_005930['Close'].max()).plot(ax=ax3)
df_000660['매매구간'].plot( ax=ax3)
plt.legend()
